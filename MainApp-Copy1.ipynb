# %%
from urllib.request import urlopen
from urllib import parse
from bs4 import BeautifulSoup
from Models.DataCollector import DataCollector
import torch.nn.functional as F
import json

# %%
class UserInspector(DataCollector):
    def __init__(self):
        self.name_to_key = {}
        self.name_to_id = {}
        self.id_to_key = {}
        self.key_to_id = {}
        with open('./metadata/name_to_key.json', 'r') as fp:
            self.name_to_key = json.load(fp)

        with open('./metadata/name_to_id.json', 'r') as fp:
            self.name_to_id = json.load(fp)

        with open('./metadata/id_to_key.json', 'r') as fp:
            self.id_to_key = json.load(fp)

        with open('./metadata/key_to_id.json', 'r') as fp:
            self.key_to_id = json.load(fp)

    def user_history_collector(self, userName):
        # url encoding (for Korean words)
        userName = parse.quote(userName)

        # open url and create bs4 Object
        html = urlopen("https://www.op.gg/summoner/userName="+userName)
        bsObject = BeautifulSoup(html, "html.parser")

        # decode userName from url encoding
        userName = parse.unquote(userName)

        # win/loss and play count
        wins = int(bsObject.find('span', 'wins').text[:-1])
        losses = int(bsObject.find('span', 'losses').text[:-1])
        total_play = wins + losses    
        win_rate = round(wins/total_play, 3)

        champ_list = bsObject.find_all("div", {'class' : 'ChampionBox Ranked'})
        champion_history = self.champ_history_setter(champ_list)            

        # this is (adapted) user_history DTO
        user_historyDTO = {
            'user_name' : userName,
            'total_play' : total_play,
            'win_rate' : win_rate,
            'champion_history' : champion_history,
        }
        return user_historyDTO

# %%
import torch

from Models.Models import AutoEncoder, Predictor, Classifier
from utils import champ_id_remap, global_win_rate, get_original_champ_id

# %%
class ChampionRecommender():
    def __init__(self):
        self.user_inspector = UserInspector()

        self.user_encoder = AutoEncoder(143, 12)
        self.user_encoder.load_state_dict(torch.load('./trained_model/user_encoder_augmented_new.pth'))

        self.item_encoder = AutoEncoder(143, 8)
        self.item_encoder.load_state_dict(torch.load('./trained_model/item_encoder2.pth'))

        self.predictor = Classifier(user_len=12, item_len=8, hidden_unit=15).eval()
        self.predictor.load_state_dict(torch.load('./trained_model/classifier_last_m.pth'))
        
        self.remapped_champ_id = champ_id_remap()
        self.global_win_rate = global_win_rate() 
        
        with open('./datasets/item_vectors_tf_idf.json', 'r') as fp:
            self.item_vectors = json.load(fp)        
        
        with open('./metadata/user_idf_table.json', 'r') as fp:
            self.idf_table = json.load(fp)

    def _recommender(self, userName):
        #try:
        user_data = self.user_inspector.user_history_collector(userName)
        win_rate_dict = self._winrate_predictior(user_data)
        return win_rate_dict
        #except:
        #    print("not a valid user. please check.")


    def _winrate_predictior(self, user_data):
        user_winrate = self._tensor_item(user_data['win_rate'])
        user_vec = self._user_vector_generator(user_data)
        played_champions = [i for i, e in enumerate(user_vec) if e != 0]
        user_vec = torch.Tensor(user_vec)
        user_vec = self.user_encoder.encoder(user_vec)
        
        win_rate_dict = dict()
        
        for key, item in self.item_vectors.items():
            if int(key) not in played_champions:
                global_win = self._tensor_item(self.global_win_rate[int(key)])
                item_vec = torch.Tensor([item])
                item_vec = self.item_encoder.encoder(item_vec)
                item_vec = item_vec.squeeze()
                
                user_vec = F.normalize(user_vec, dim=0)
                item_vec = F.normalize(item_vec, dim=0)
                
                prediction = self.predictor(user_vec, item_vec)
                prediction = torch.max(prediction, dim=0)
                win_rate_dict[key] = prediction[0]
        return win_rate_dict
    
    def _dict_origin_mapper(self, recommend_dict):
        original_recommend_dict = dict()
        for remapped_id, score in recommend_dict.items():
            original_id = get_original_champ_id(self.remapped_champ_id, int(remapped_id))
            original_name = self.user_inspector.key_to_id[str(original_id)]
            original_recommend_dict[original_name] = recommend_dict[remapped_id]
        return original_recommend_dict
            
            
    def _user_vector_generator(self, user_data):
        user_win_rate = user_data['win_rate']
        play_count_vector = [0 for x in range(143)]

        for champ_history in user_data['champion_history']:
            original_champ_id = champ_history['champion_key']
            champ_idx = self.remapped_champ_id[original_champ_id]

            max_play_count = self._get_max_play_count(user_data)
            measured_score = (champ_history['play_count'] / max_play_count) * self.idf_table[str(champ_idx)]
            play_count_vector[champ_idx] = measured_score
        
        return play_count_vector

    
    def _get_max_play_count(self, user_data):
        """
        Get count of maximally played champion for user_name
        """
        max_play_count = 0

        for champ_history in user_data['champion_history']:
            champ_play_count = champ_history['play_count']
            if max_play_count < champ_play_count:
                max_play_count = champ_play_count

        return max_play_count

    
    def _tensor_item(self, item):
        return torch.Tensor([item])

# %%
test = ChampionRecommender()

# %%
test_output = test._recommender('만년동핵폭탄')

# %%
result = test._dict_origin_mapper(test_output)

# %%
import operator
sorted_result = sorted(result.items(), key=operator.itemgetter(1), reverse=True)

# %%
sorted_result
# Out:
# [('Kaisa', tensor(0.7433, grad_fn=<MaxBackward0>)),
#  ('Ezreal', tensor(0.7375, grad_fn=<MaxBackward0>)),
#  ('Veigar', tensor(0.7339, grad_fn=<MaxBackward0>)),
#  ('Shaco', tensor(0.7325, grad_fn=<MaxBackward0>)),
#  ('Zac', tensor(0.7295, grad_fn=<MaxBackward0>)),
#  ('MissFortune', tensor(0.7249, grad_fn=<MaxBackward0>)),
#  ('Jhin', tensor(0.7241, grad_fn=<MaxBackward0>)),
#  ('Sivir', tensor(0.7086, grad_fn=<MaxBackward0>)),
#  ('Karthus', tensor(0.7026, grad_fn=<MaxBackward0>)),
#  ('Lucian', tensor(0.6992, grad_fn=<MaxBackward0>)),
#  ('Kindred', tensor(0.6944, grad_fn=<MaxBackward0>)),
#  ('Caitlyn', tensor(0.6941, grad_fn=<MaxBackward0>)),
#  ('Vayne', tensor(0.6874, grad_fn=<MaxBackward0>)),
#  ('Xayah', tensor(0.6735, grad_fn=<MaxBackward0>)),
#  ('Fiora', tensor(0.6707, grad_fn=<MaxBackward0>)),
#  ('Vladimir', tensor(0.6566, grad_fn=<MaxBackward0>)),
#  ('Renekton', tensor(0.6472, grad_fn=<MaxBackward0>)),
#  ('Aatrox', tensor(0.6444, grad_fn=<MaxBackward0>)),
#  ('Syndra', tensor(0.6198, grad_fn=<MaxBackward0>)),
#  ('Shen', tensor(0.6198, grad_fn=<MaxBackward0>)),
#  ('LeeSin', tensor(0.6132, grad_fn=<MaxBackward0>)),
#  ('Zed', tensor(0.5972, grad_fn=<MaxBackward0>)),
#  ('Ornn', tensor(0.5900, grad_fn=<MaxBackward0>)),
#  ('Teemo', tensor(0.5776, grad_fn=<MaxBackward0>)),
#  ('Twitch', tensor(0.5747, grad_fn=<MaxBackward0>)),
#  ('Nasus', tensor(0.5739, grad_fn=<MaxBackward0>)),
#  ('Rumble', tensor(0.5730, grad_fn=<MaxBackward0>)),
#  ('Elise', tensor(0.5675, grad_fn=<MaxBackward0>)),
#  ('XinZhao', tensor(0.5646, grad_fn=<MaxBackward0>)),
#  ('Ahri', tensor(0.5634, grad_fn=<MaxBackward0>)),
#  ('Nocturne', tensor(0.5606, grad_fn=<MaxBackward0>)),
#  ('Bard', tensor(0.5602, grad_fn=<MaxBackward0>)),
#  ('Fizz', tensor(0.5591, grad_fn=<MaxBackward0>)),
#  ('Viktor', tensor(0.5556, grad_fn=<MaxBackward0>)),
#  ('Graves', tensor(0.5518, grad_fn=<MaxBackward0>)),
#  ('Yasuo', tensor(0.5478, grad_fn=<MaxBackward0>)),
#  ('Tristana', tensor(0.5350, grad_fn=<MaxBackward0>)),
#  ('Kassadin', tensor(0.5298, grad_fn=<MaxBackward0>)),
#  ('Hecarim', tensor(0.5261, grad_fn=<MaxBackward0>)),
#  ('RekSai', tensor(0.5159, grad_fn=<MaxBackward0>)),
#  ('Ekko', tensor(0.5015, grad_fn=<MaxBackward0>)),
#  ('Khazix', tensor(0.4976, grad_fn=<MaxBackward0>)),
#  ('Annie', tensor(0.4932, grad_fn=<MaxBackward0>)),
#  ('Fiddlesticks', tensor(0.4926, grad_fn=<MaxBackward0>)),
#  ('Gragas', tensor(0.4878, grad_fn=<MaxBackward0>)),
#  ('Urgot', tensor(0.4871, grad_fn=<MaxBackward0>)),
#  ('Sylas', tensor(0.4831, grad_fn=<MaxBackward0>)),
#  ('Velkoz', tensor(0.4759, grad_fn=<MaxBackward0>)),
#  ('Gangplank', tensor(0.4758, grad_fn=<MaxBackward0>)),
#  ('Zoe', tensor(0.4702, grad_fn=<MaxBackward0>)),
#  ('Chogath', tensor(0.4601, grad_fn=<MaxBackward0>)),
#  ('TwistedFate', tensor(0.4537, grad_fn=<MaxBackward0>)),
#  ('Leblanc', tensor(0.4410, grad_fn=<MaxBackward0>)),
#  ('Lulu', tensor(0.4377, grad_fn=<MaxBackward0>)),
#  ('Jinx', tensor(0.4375, grad_fn=<MaxBackward0>)),
#  ('Rammus', tensor(0.4346, grad_fn=<MaxBackward0>)),
#  ('Swain', tensor(0.4341, grad_fn=<MaxBackward0>)),
#  ('Camille', tensor(0.4335, grad_fn=<MaxBackward0>)),
#  ('Illaoi', tensor(0.4322, grad_fn=<MaxBackward0>)),
#  ('Akali', tensor(0.4319, grad_fn=<MaxBackward0>)),
#  ('Orianna', tensor(0.4307, grad_fn=<MaxBackward0>)),
#  ('Irelia', tensor(0.4298, grad_fn=<MaxBackward0>)),
#  ('Ryze', tensor(0.4272, grad_fn=<MaxBackward0>)),
#  ('Blitzcrank', tensor(0.3948, grad_fn=<MaxBackward0>)),
#  ('Zilean', tensor(0.3822, grad_fn=<MaxBackward0>)),
#  ('Kalista', tensor(0.3780, grad_fn=<MaxBackward0>)),
#  ('Kayn', tensor(0.3728, grad_fn=<MaxBackward0>)),
#  ('Ashe', tensor(0.3660, grad_fn=<MaxBackward0>)),
#  ('Taric', tensor(0.3628, grad_fn=<MaxBackward0>)),
#  ('Thresh', tensor(0.3590, grad_fn=<MaxBackward0>)),
#  ('Nidalee', tensor(0.3579, grad_fn=<MaxBackward0>)),
#  ('Amumu', tensor(0.3571, grad_fn=<MaxBackward0>)),
#  ('Neeko', tensor(0.3565, grad_fn=<MaxBackward0>)),
#  ('Pyke', tensor(0.3561, grad_fn=<MaxBackward0>)),
#  ('Talon', tensor(0.3531, grad_fn=<MaxBackward0>)),
#  ('Nunu', tensor(0.3526, grad_fn=<MaxBackward0>)),
#  ('Riven', tensor(0.3502, grad_fn=<MaxBackward0>)),
#  ('Sion', tensor(0.3501, grad_fn=<MaxBackward0>)),
#  ('MasterYi', tensor(0.3439, grad_fn=<MaxBackward0>)),
#  ('Draven', tensor(0.3409, grad_fn=<MaxBackward0>)),
#  ('Vi', tensor(0.3275, grad_fn=<MaxBackward0>)),
#  ('DrMundo', tensor(0.3262, grad_fn=<MaxBackward0>)),
#  ('TahmKench', tensor(0.3103, grad_fn=<MaxBackward0>)),
#  ('Maokai', tensor(0.3003, grad_fn=<MaxBackward0>)),
#  ('Corki', tensor(0.2966, grad_fn=<MaxBackward0>)),
#  ('Yorick', tensor(0.2959, grad_fn=<MaxBackward0>)),
#  ('AurelionSol', tensor(0.2898, grad_fn=<MaxBackward0>)),
#  ('Sona', tensor(0.2856, grad_fn=<MaxBackward0>)),
#  ('Trundle', tensor(0.2849, grad_fn=<MaxBackward0>)),
#  ('Gnar', tensor(0.2834, grad_fn=<MaxBackward0>)),
#  ('Evelynn', tensor(0.2814, grad_fn=<MaxBackward0>)),
#  ('Cassiopeia', tensor(0.2781, grad_fn=<MaxBackward0>)),
#  ('JarvanIV', tensor(0.2694, grad_fn=<MaxBackward0>)),
#  ('Olaf', tensor(0.2660, grad_fn=<MaxBackward0>)),
#  ('Taliyah', tensor(0.2648, grad_fn=<MaxBackward0>)),
#  ('Volibear', tensor(0.2599, grad_fn=<MaxBackward0>)),
#  ('Mordekaiser', tensor(0.2595, grad_fn=<MaxBackward0>)),
#  ('Xerath', tensor(0.2594, grad_fn=<MaxBackward0>)),
#  ('Kled', tensor(0.2447, grad_fn=<MaxBackward0>)),
#  ('Kayle', tensor(0.2429, grad_fn=<MaxBackward0>)),
#  ('Tryndamere', tensor(0.2320, grad_fn=<MaxBackward0>)),
#  ('Udyr', tensor(0.2288, grad_fn=<MaxBackward0>)),
#  ('Malzahar', tensor(0.2279, grad_fn=<MaxBackward0>)),
#  ('Heimerdinger', tensor(0.2276, grad_fn=<MaxBackward0>)),
#  ('Lissandra', tensor(0.2191, grad_fn=<MaxBackward0>)),
#  ('Warwick', tensor(0.2177, grad_fn=<MaxBackward0>)),
#  ('Ivern', tensor(0.2173, grad_fn=<MaxBackward0>)),
#  ('Malphite', tensor(0.2149, grad_fn=<MaxBackward0>)),
#  ('MonkeyKing', tensor(0.2143, grad_fn=<MaxBackward0>)),
#  ('Diana', tensor(0.2102, grad_fn=<MaxBackward0>)),
#  ('Katarina', tensor(0.2038, grad_fn=<MaxBackward0>)),
#  ('Rengar', tensor(0.2007, grad_fn=<MaxBackward0>)),
#  ('Singed', tensor(0.2006, grad_fn=<MaxBackward0>)),
#  ('Sejuani', tensor(0.1975, grad_fn=<MaxBackward0>)),
#  ('Varus', tensor(0.1921, grad_fn=<MaxBackward0>)),
#  ('Skarner', tensor(0.1909, grad_fn=<MaxBackward0>)),
#  ('Nami', tensor(0.1891, grad_fn=<MaxBackward0>)),
#  ('Quinn', tensor(0.1873, grad_fn=<MaxBackward0>)),
#  ('Rakan', tensor(0.1866, grad_fn=<MaxBackward0>)),
#  ('Azir', tensor(0.1807, grad_fn=<MaxBackward0>)),
#  ('Poppy', tensor(0.1612, grad_fn=<MaxBackward0>)),
#  ('Ziggs', tensor(0.1597, grad_fn=<MaxBackward0>)),
#  ('Anivia', tensor(0.1551, grad_fn=<MaxBackward0>)),
#  ('Nautilus', tensor(0.1535, grad_fn=<MaxBackward0>)),
#  ('KogMaw', tensor(0.1334, grad_fn=<MaxBackward0>)),
#  ('Braum', tensor(0.1305, grad_fn=<MaxBackward0>)),
#  ('Shyvana', tensor(0.1198, grad_fn=<MaxBackward0>)),
#  ('Brand', tensor(0.0430, grad_fn=<MaxBackward0>)),
#  ('Galio', tensor(0.0428, grad_fn=<MaxBackward0>)),
#  ('Janna', tensor(0.0089, grad_fn=<MaxBackward0>)),
#  ('Morgana', tensor(-0.0125, grad_fn=<MaxBackward0>)),
#  ('Karma', tensor(-0.0364, grad_fn=<MaxBackward0>)),
#  ('Leona', tensor(-0.0553, grad_fn=<MaxBackward0>)),
#  ('Alistar', tensor(-0.0603, grad_fn=<MaxBackward0>)),
#  ('Zyra', tensor(-0.1273, grad_fn=<MaxBackward0>)),
#  ('Soraka', tensor(-0.1393, grad_fn=<MaxBackward0>))]
