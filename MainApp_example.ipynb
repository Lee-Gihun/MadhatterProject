# %% [markdown]
# import recommender system

# %%
from ChampionRecommender import ChampionRecommender

# %% [markdown]
# make an instance

# %%
test = ChampionRecommender()

# %% [markdown]
# query user name. the results are sorted recommendation score dictionary.
# use top-5 result from the dictionary.

# %%
test.recommender('만년동핵폭탄')
# Out:
# ({'Renekton': 0.008066282600071282,
#   'Nasus': 0.007447264102753252,
#   'Yasuo': 0.0074443702655844395,
#   'Vladimir': 0.007049993159156292,
#   'Malphite': 0.007070199895789847,
#   'Ezreal': 0.006491792161017656,
#   'Irelia': 0.006275574764888733,
#   'Vayne': 0.006145055294316262,
#   'Yorick': 0.006015338470018469,
#   'Zed': 0.006047519242647104,
#   'Riven': 0.005741220562905073,
#   'Lucian': 0.005774508764920756,
#   'Sylas': 0.005687926868372596,
#   'Urgot': 0.005554871081223246,
#   'Caitlyn': 0.005473585180239752,
#   'Sivir': 0.00532741580074653,
#   'Fiora': 0.0052648359242710285,
#   'Teemo': 0.0052602112178690725,
#   'Blitzcrank': 0.005237614477297757,
#   'Akali': 0.005284710946911945,
#   'Kayle': 0.005123616302316078,
#   'Sion': 0.005122190636192681,
#   'Morgana': 0.005052989974291995,
#   'Thresh': 0.005060168810997857,
#   'Hecarim': 0.004934524805750698,
#   'Jinx': 0.004928491345490328,
#   'Ashe': 0.004831655811320525,
# ...
